# %% [markdown]
# <a href="https://colab.research.google.com/github/lgsus-wi/Login/blob/main/PCC_Classes_(Chapter_9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#9-1
class Restaurant:
  def __init__(self, restaurant_name, cuisine_type):
    self.restaurant_name = restaurant_name
    self.cuisine_type = cuisine_type

  def describe_restaurant(self):
    print(f"El nombre del restaurante es: {self.restaurant_name.title()}.")
    print(f"El tipo de comida es: {self.cuisine_type.title()}.")

  def open_restaurant(self):
    print("The restaurant is open!")

restaurant = Restaurant('olive garden', 'italiana')
print(f"{restaurant.restaurant_name}\n{restaurant.cuisine_type}")
restaurant.describe_restaurant()
restaurant.open_restaurant()
# Out:
# olive garden
# italiana
# El nombre del restaurante es: Olive Garden.
# El tipo de comida es: Italiana.
# The restaurant is open!

# %%
#9-2
class Restaurant:
  def __init__(self, restaurant_name, cuisine_type):
    self.restaurant_name = restaurant_name
    self.cuisine_type = cuisine_type

  def describe_restaurant(self):
    print(f"El nombre del restaurante es: {self.restaurant_name.title()}.")
    print(f"El tipo de comida es: {self.cuisine_type.title()}.")

  def open_restaurant(self):
    print("The restaurant is open!")

res_1 = Restaurant('parkside restaurant', 'family restaurant')
res_1.describe_restaurant()

res_2 = Restaurant('olive garden', 'italiana')
res_2.describe_restaurant()

res_3 = Restaurant('chilis', 'mexicana/americana')
res_3.describe_restaurant()
# Out:
# El nombre del restaurante es: Parkside Restaurant.
# El tipo de comida es: Family Restaurant.
# El nombre del restaurante es: Olive Garden.
# El tipo de comida es: Italiana.
# El nombre del restaurante es: Chilis.
# El tipo de comida es: Mexicana/Americana.

# %%
#9-3
class User:
  def __init__(self, first_name, last_name, age, nationality):
    self.first_name = first_name
    self.last_name = last_name
    self.age = age
    self. nationality = nationality

  def describe_user(self):
    print(f"\nName: {self.first_name.title()} {self.last_name.title()}")
    print(f"Age: {self.age}")
    print(f"Nationality: {self.nationality.title()}")

  def greet_user(self):
    print(f"\tHola, {self.first_name.title()}. Hope you are allright!")

user_1 = User('amanda', 'garcia', 29, 'colombia')
user_1.describe_user()
user_1.greet_user()

user_2 = User('juan', 'arteta', 24, 'venezuela')
user_2.describe_user()
user_2.greet_user()

user_3 = User('hugo', 'espinoza', 35, 'peru')
user_3.describe_user()
user_3.greet_user()
# Out:
# Name: Amanda Garcia
# Age: 29
# Nationality: Colombia
# 	Hola, Amanda. Hope you are allright!
#
# Name: Juan Arteta
# Age: 24
# Nationality: Venezuela
# 	Hola, Juan. Hope you are allright!
#
# Name: Hugo Espinoza
# Age: 35
# Nationality: Peru
# 	Hola, Hugo. Hope you are allright!

# %%
class Restaurant:
  def __init__(self, restaurant_name, cuisine_type):
    self.restaurant_name = restaurant_name
    self.cuisine_type = cuisine_type
    #self.number_served = 0

  def describe_restaurant(self):
    print(f"El nombre del restaurante es: {self.restaurant_name.title()}.")
    print(f"El tipo de comida es: {self.cuisine_type.title()}.")

  def open_restaurant(self):
    print("The restaurant is open!")

  def set_number_served(self, served):
    self.number_served = served

  def increase_served(self, incre):
    self.number_served += incre

  def re_number_served(self):
    print(f"El numero de personas servidas es: {self.number_served}")


restaurant = Restaurant('olive garden', 'italiana')
print(f"{restaurant.restaurant_name}\n{restaurant.cuisine_type}")
restaurant.describe_restaurant()
#restaurant.number_served = 20
#print(f"El numero de personas atendidas es: {restaurant.number_served}")
restaurant.set_number_served(56)
restaurant.re_number_served()
restaurant.increase_served(14)
restaurant.re_number_served()
restaurant.open_restaurant()
# Out:
# olive garden
# italiana
# El nombre del restaurante es: Olive Garden.
# El tipo de comida es: Italiana.
# El numero de personas servidas es: 56
# El numero de personas servidas es: 70
# The restaurant is open!

# %%
#9-5
class User:
  def __init__(self, first_name, last_name, age, nationality):
    self.first_name = first_name
    self.last_name = last_name
    self.age = age
    self. nationality = nationality
    self.login_attempts = 0

  def increment_login_attempts(self):
    self.login_attempts += 1

  def reset_login_attempts(self):
    self.login_attempts = 0

  def count_attempts(self):
    print(f"Numero de intentos de login: {self.login_attempts}")

  def describe_user(self):
    print(f"\nName: {self.first_name.title()} {self.last_name.title()}")
    print(f"Age: {self.age}")
    print(f"Nationality: {self.nationality.title()}")

  def greet_user(self):
    print(f"\tHola, {self.first_name.title()}. Hope you are allright!")

n_user = User('jesus', 'rangel', 29, 'colombia')
n_user.increment_login_attempts()
n_user.increment_login_attempts()
n_user.increment_login_attempts()
n_user.increment_login_attempts()
n_user.increment_login_attempts()
n_user.increment_login_attempts()
n_user.increment_login_attempts()
n_user.count_attempts()
n_user.reset_login_attempts()
n_user.count_attempts()
# Out:
# Numero de intentos de login: 7
# Numero de intentos de login: 0
